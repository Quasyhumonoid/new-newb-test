# %%
empty_list=[]
list_str=['camry','accord','civic','corolla']
list_int=[1,2,3,4,5]
list_float=[1.2,2.3,3.4]
print("1:", list_str)
print("2:",list_str[0])
print("3:",list_str[-1])
list_str.append('elantra')
print("4:",list_str[-1])
list_str.insert(2, 'sentra')
print("5:",list_str)
list_str.extend(['optima','soul'])
print("6:",list_str)
print("7:",list_str.index("elantra"))
list_str.remove('camry')
print("8:",list_str)
list2=['focus','fiesta','prius','cooper','clubman','beetle','jetta','golf']
cars_list = list_str + list2
print("9:",cars_list)
list2.index
cars_list.reverse()
print ("10:",cars_list)
list2.pop()
print ("11:",list2)
cars_list.count('civic')
list2.clear()
list2.extend(['accord','accord','civic'])
print("12:",set(list2))
cars_list.sort()
print("13:",cars_list)
import copy
list_copy = copy.deepcopy(cars_list)
print("14:",list_copy)
cars_list.append("cavelier")
print("15:",list_copy)
print("16:",list_copy)
cars2 = list_copy
list_copy.pop()
print("17:",cars2)
del cars2
cars3 = copy.copy(list_copy)
list_copy.append("sentra")
print("18:",list_copy)
print("19:",cars3)
list_num=[10, 20, 50, 70, 60, 15]
print("20:",list_num)
print("21:",max(list_num))
list_num2=sorted(list_num)
print("22:",list_num2)
print("23:",sum(list_num2))
print("24:",all([0]))
print("25:",all([1,0]))
print("26:",all([1]))
print("27:",any([1,0]))
# Out:
# 1: ['camry', 'accord', 'civic', 'corolla']
# 2: camry
# 3: corolla
# 4: elantra
# 5: ['camry', 'accord', 'sentra', 'civic', 'corolla', 'elantra']
# 6: ['camry', 'accord', 'sentra', 'civic', 'corolla', 'elantra', 'optima', 'soul']
# 7: 5
# 8: ['accord', 'sentra', 'civic', 'corolla', 'elantra', 'optima', 'soul']
# 9: ['accord', 'sentra', 'civic', 'corolla', 'elantra', 'optima', 'soul', 'focus', 'fiesta', 'prius', 'cooper', 'clubman', 'beetle', 'jetta', 'golf']
# 10: ['golf', 'jetta', 'beetle', 'clubman', 'cooper', 'prius', 'fiesta', 'focus', 'soul', 'optima', 'elantra', 'corolla', 'civic', 'sentra', 'accord']
# 11: ['focus', 'fiesta', 'prius', 'cooper', 'clubman', 'beetle', 'jetta']
# 12: {'accord', 'civic'}
# 13: ['accord', 'beetle', 'civic', 'clubman', 'cooper', 'corolla', 'elantra', 'fiesta', 'focus', 'golf', 'jetta', 'optima', 'prius', 'sentra', 'soul']
# ...

# %%
#list slicing
#beginning indexes are inclusive and end indexes are exclusive
print("1:",len(cars3))
print("2:",cars3[5])
print("3:",cars3[0:4])
print("4:",cars3[:3])
print("5:",cars3[3:])
print("6:",cars3[-4:-2])
#adding step size of 2 with :2 at the end
print("7:",cars3[:8:2])
#to step through whole list requires the extra : but no beginning or end delineated
print("8:",cars3[::3])
print("9:",cars3[::-1])
# Out:
# 1: 14
# 2: corolla
# 3: ['accord', 'beetle', 'civic', 'clubman']
# 4: ['accord', 'beetle', 'civic']
# 5: ['clubman', 'cooper', 'corolla', 'elantra', 'fiesta', 'focus', 'golf', 'jetta', 'optima', 'prius', 'sentra']
# 6: ['jetta', 'optima']
# 7: ['accord', 'civic', 'cooper', 'elantra']
# 8: ['accord', 'clubman', 'elantra', 'golf', 'prius']
# 9: ['sentra', 'prius', 'optima', 'jetta', 'golf', 'focus', 'fiesta', 'elantra', 'corolla', 'cooper', 'clubman', 'civic', 'beetle', 'accord']

# %%
#String slicing
X = 'World'
print("1:", X[0])
print("2:", X[-2])
a, b, c, d, e = X
print("3:", a, b, c, d, e)
a, b, _, _, _, = X
print("3:", _)
place = input('Where are you from?: ')
length = len(place)
length //= 2
print("4:", place[:length])
print("5:", place.startswith('n'))
print("6:", place.endswith('town'))
print("7:", place.count('l'))
print("8:", place.upper())
print("9:", place.lower())
pos = place.find('town')
print("10:", place[pos:])
filename = 'sherlock.s01e02.1080'
Split = filename.split('.')
print("11:", Split)
join_char=' '
print("12:", join_char.join(Split))
print("13:", "*".join(Split))
# Out:
# 1: W
# 2: l
# 3: W o r l d
# 3: d
# Where are you from?: marshalltown
# 4: marsha
# 5: False
# 6: True
# 7: 2
# 8: MARSHALLTOWN
# 9: marshalltown
# 10: town
# 11: ['sherlock', 's01e02', '1080']
# 12: sherlock s01e02 1080
# 13: sherlock*s01e02*1080

# %%
#tuples
tuple1 = ()
print("1:", type(tuple1))
tuple1 = (1, 2, 3)
tuple2 = (3, 4, 5)
tuple3 = (tuple1 + tuple2)
print("2:", tuple3)
tuple4 = 5, 6, 'g'
print("3:", type(tuple4))
tuple5 = tuple1, tuple2, tuple4
print("4:", tuple5)
var1, var2, var3 = tuple4
print("5:", var3)
print("6:", tuple5[2][2])
print("7:", 'g' in tuple4)
print("8:", sum(tuple1))
print("9:", list(tuple5))
print("10:", set(tuple3))
#you can't insert or remove values from tuples
#you can edit lists if they're in a tuple though
tuple7 = (1,2,3,4,5,6)
tuple8 = ('a','b','c','d','e','f')
zipped=zip(tuple7, tuple8)
print("11:", zipped)
coor = tuple(zipped)
print("12:", coor)
tuple9, tuple10 = zip(*coor)
print("13:", tuple9, tuple10)
# Out:
# 1: <class 'tuple'>
# 2: (1, 2, 3, 3, 4, 5)
# 3: <class 'tuple'>
# 4: ((1, 2, 3), (3, 4, 5), (5, 6, 'g'))
# 5: g
# 6: g
# 7: True
# 8: 6
# 9: [(1, 2, 3), (3, 4, 5), (5, 6, 'g')]
# 10: {1, 2, 3, 4, 5}
# 11: <zip object at 0x0000024D57E0C8C0>
# 12: ((1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e'), (6, 'f'))
# 13: (1, 2, 3, 4, 5, 6) ('a', 'b', 'c', 'd', 'e', 'f')

# %%
#dictionaries
diction = {"a":25, "b":50, "c":20}
type(diction)
numb = (1,2,3)
tub1 = ["mom", "dad", "spouse"]
print("1:", tub1)
tub2 = ['Pat', 'Tom', 'Em']
print("2:", tub2)
fam=zip(tub1, tub2)
diction2 = dict(fam)
print("3:", diction2)
print("4:", diction2['mom'])
print("5:", diction2.keys())
"dad" in diction2.keys()
print("6:", diction2.values())
print("7:", diction2.get('spouse'))
print("8:", sorted(diction2))
print("9:", sorted(diction2, reverse=True))
print("10:", sorted(diction2.values()))
print("11:", diction2.items())
spouse = diction2.pop("spouse")
print("12:", diction2)
print("13:", spouse)
diction2.popitem()
print("14:", diction2)
diction3= {"spouse":"Em", "dad":"Tom","mom":"Pat"}
diction2.update(diction3)
print("15:", diction2)
diction3.clear
del diction3
# Out:
# 1: ['mom', 'dad', 'spouse']
# 2: ['Pat', 'Tom', 'Em']
# 3: {'mom': 'Pat', 'dad': 'Tom', 'spouse': 'Em'}
# 4: Pat
# 5: dict_keys(['mom', 'dad', 'spouse'])
# 6: dict_values(['Pat', 'Tom', 'Em'])
# 7: Em
# 8: ['dad', 'mom', 'spouse']
# 9: ['spouse', 'mom', 'dad']
# 10: ['Em', 'Pat', 'Tom']
# 11: dict_items([('mom', 'Pat'), ('dad', 'Tom'), ('spouse', 'Em')])
# 12: {'mom': 'Pat', 'dad': 'Tom'}
# 13: Em
# 14: {'mom': 'Pat'}
# 15: {'mom': 'Pat', 'spouse': 'Em', 'dad': 'Tom'}

# %%
#sets order doesn't matter, no duplicates, no lists in set (only immutable values)
numbers = {1,5,2,7,6}
print("1:", numbers)
type(numbers)
numbers.add(3)
print("2:", numbers)
numbers.discard(7)
#discard doesn't care if the item was actually on the list, remove will fail if the item wasn't there
print("3:", numbers)
numbers.remove(2)
print("4:", numbers)
numbers.clear()
print("5:", numbers)
numbers1={2,4,6,8,10}
print("6:", numbers1)
numbers2 = {1,5,7,9,11}
print("7:", numbers2)
numbers1=numbers1.union(numbers2)
numbers = {1,2,3,4,5}
numbers3=numbers.intersection(numbers,numbers2)
print("8:", numbers3)
numbers4=numbers.difference(numbers3,numbers2)
print("9:", numbers4)
numbers.intersection_update(numbers3)
print("10:", numbers)
what=numbers.isdisjoint(numbers4)
print("11:", what)
what=numbers.isdisjoint(numbers3)
print("12:", what)
what=numbers.issubset(numbers3)
print("13:", what)
what=numbers3.issuperset(numbers)
print("14:", what)
# Out:
# 1: {1, 2, 5, 6, 7}
# 2: {1, 2, 3, 5, 6, 7}
# 3: {1, 2, 3, 5, 6}
# 4: {1, 3, 5, 6}
# 5: set()
# 6: {2, 4, 6, 8, 10}
# 7: {1, 5, 7, 9, 11}
# 8: {1, 5}
# 9: {2, 3, 4}
# 10: {1, 5}
# 11: True
# 12: False
# 13: True
# 14: True
